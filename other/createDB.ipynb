# %%
# Dependencies
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.orm import Session
import pandas as pd

# %%
# Declarative base
Base = declarative_base()

# %%
# Create the clientDB class
class Client(Base):
    __tablename__ = 'clients'
    id = Column(Integer, primary_key=True)    
    last_name = Column(String)
    first_name = Column(String)
    unit = Column(String)   
    street_number = Column(String)
    street_name = Column(String)
    street_type = Column(String)
    suburb = Column(String)
    postcode = Column(String)
    full_address = Column(String)
    number_adults = Column(Integer)
    number_children = Column(Integer)
    lat = Column(Float)
    long = Column(Float)
    primary_phone = Column(String)
    emergency_phone = Column(String)
    risk = Column(String)

# %%
# Create a connection to a SQLite and crate table
Base.metadata.tables
engine = create_engine('sqlite:///CRM_data.sqlite')
Base.metadata.create_all(engine)

# %%
# Create Session object
session = Session(bind=engine)

# %%
# Add data from CSV
df = pd.read_csv("../data/CRM_data.csv")

# %%
for row in df.index:
    session.add(Client(last_name=df.Last_Name[row],
                        first_name=df.First_Name[row],
                        unit=df.Unit[row],
                        street_number=df.Street_Number[row],
                        street_name=df.Street_Name[row],
                        street_type=df.Street_Type[row],
                        suburb=df.Suburb[row],
                        postcode=df.Postcode[row],
                        full_address=df.Full_Address[row],
                        number_adults=df.Number_Adults[row],
                        number_children=df.Number_Children[row],
                        lat=df.Lat[row],
                        long=df.Long[row],
                        primary_phone=df.Primary_Phone[row],
                        emergency_phone=df.Emergency_Phone[row],
                        risk=df.Risk[row],
                        ))

# %%
# Add these objects to the session
session.commit()

# %%
# Example query
# session.query(Client.last_name, Client.first_name, Client.risk).all()
# Out:
# [('Abbott', 'Venus', 'LOW'),
#  ('Acevedo', 'Hayfa', 'MED'),
#  ('Adkins', 'Thomas', 'LOW'),
#  ('Aguilar', 'Kyle', 'LOW'),
#  ('Aguirre', 'Melinda', 'LOW'),
#  ('Albert', 'Forrest', 'LOW'),
#  ('Alexander', 'Dorothy', 'MED'),
#  ('Alford', 'Sage', 'LOW'),
#  ('Allison', 'Nelle', 'MED'),
#  ('Allison', 'Quinlan', 'LOW'),
#  ('Alvarado', 'Phillip', 'LOW'),
#  ('Alvarez', 'Samuel', 'MED'),
#  ('Armstrong', 'Amery', 'LOW'),
#  ('Armstrong', 'Grace', 'LOW'),
#  ('Armstrong', 'Kyra', 'MED'),
#  ('Atkinson', 'Heather', 'MED'),
#  ('Avery', 'Megan', 'MED'),
#  ('Ayala', 'Howard', 'MED'),
#  ('Ayers', 'Ignatius', 'LOW'),
#  ('Bailey', 'Nola', 'LOW'),
#  ('Baker', 'Bernard', 'LOW'),
#  ('Baker', 'Beau', 'MED'),
#  ('Ballard', 'Quon', 'LOW'),
#  ('Barker', 'Nita', 'LOW'),
#  ('Barlow', 'Sigourney', 'MED'),
#  ('Barton', 'Slade', 'MED'),
#  ('Barton', 'Aristotle', 'MED'),
#  ('Bass', 'Glenna', 'LOW'),
#  ('Baxter', 'Kerry', 'LOW'),
#  ('Beck', 'Tasha', 'LOW'),
#  ('Bell', 'Palmer', 'LOW'),
#  ('Benjamin', 'Nerea', 'LOW'),
#  ('Benson', 'Nicole', 'LOW'),
#  ('Berg', 'Jonah', 'HIGH'),
#  ('Best', 'Lacota', 'MED'),
#  ('Blackburn', 'Moana', 'LOW'),
#  ('Blackwell', 'Alec', 'LOW'),
#  ('Blackwell', 'Salvador', 'MED'),
#  ('Blackwell', 'Jarrod', 'MED'),
#  ('Blake', 'Keith', 'MED'),
#  ('Blankenship', 'Sade', 'MED'),
#  ('Blankenship', 'Merritt', 'MED'),
#  ('Blankenship', 'Petra', 'LOW'),
#  ('Bond', 'Kadeem', 'MED'),
#  ('Boone', 'Alden', 'MED'),
#  ('Bradford', 'Barclay', 'LOW'),
#  ('Bradshaw', 'Kimberley', 'LOW'),
#  ('Brady', 'Ava', 'MED'),
#  ('Branch', 'Mufutau', 'MED'),
#  ('Brewer', 'Hope', 'MED'),
#  ('Browning', 'Veronica', 'LOW'),
#  ('Bruce', 'Fletcher', 'HIGH'),
#  ('Bryant', 'Nelle', 'MED'),
#  ('Buchanan', 'Charity', 'MED'),
#  ('Buchanan', 'Joseph', 'LOW'),
#  ('Buckley', 'Yvette', 'MED'),
#  ('Burris', 'Hanae', 'LOW'),
#  ('Cabrera', 'Kelly', 'LOW'),
#  ('Cain', 'Kasper', 'MED'),
#  ('Caldwell', 'Ishmael', 'LOW'),
#  ('Campos', 'Matthew', 'MED'),
#  ('Cardenas', 'Price', 'LOW'),
#  ('Carrillo', 'Jonas', 'LOW'),
#  ('Carrillo', 'Scarlet', 'LOW'),
#  ('Carrillo', 'Christian', 'MED'),
#  ('Carroll', 'Christopher', 'LOW'),
#  ('Casey', 'Helen', 'MED'),
#  ('Cash', 'Rowan', 'LOW'),
#  ('Castaneda', 'Barclay', 'LOW'),
#  ('Castillo', 'Abraham', 'LOW'),
#  ('Chambers', 'Abbot', 'LOW'),
#  ('Chang', 'Galvin', 'MED'),
#  ('Chang', 'Victoria', 'LOW'),
#  ('Chang', 'Brent', 'MED'),
#  ('Chen', 'Frances', 'LOW'),
#  ('Chen', 'Holmes', 'LOW'),
#  ('Church', 'Davis', 'HIGH'),
#  ('Clarke', 'Orli', 'MED'),
#  ('Clements', 'Tad', 'LOW'),
#  ('Clements', 'Clarke', 'LOW'),
#  ('Cleveland', 'Sigourney', 'MED'),
#  ('Cline', 'Serena', 'LOW'),
#  ('Cochran', 'Yardley', 'MED'),
#  ('Coffey', 'Mark', 'LOW'),
#  ('Cohen', 'Hedda', 'LOW'),
#  ('Coleman', 'Jorden', 'LOW'),
#  ('Collier', 'Germaine', 'LOW'),
#  ('Collier', 'Lane', 'LOW'),
#  ('Collier', 'Norman', 'LOW'),
#  ('Compton', 'Kevin', 'LOW'),
#  ('Conner', 'Dante', 'LOW'),
#  ('Conrad', 'Althea', 'LOW'),
#  ('Conrad', 'Amir', 'LOW'),
#  ('Conway', 'Jameson', 'MED'),
#  ('Conway', 'Jemima', 'MED'),
#  ('Cooley', 'Chiquita', 'HIGH'),
#  ('Cooley', 'Yoshio', 'LOW'),
#  ('Cotton', 'Teagan', 'LOW'),
#  ('Cotton', 'Ifeoma', 'MED'),
#  ('Cox', 'Nola', 'LOW'),
#  ('Cox', 'Yvonne', 'LOW'),
#  ('Craft', 'Xanthus', 'LOW'),
#  ('Craig', 'Lucian', 'LOW'),
#  ('Crosby', 'Roary', 'LOW'),
#  ('Cross', 'Freya', 'LOW'),
#  ('Cummings', 'Aileen', 'LOW'),
#  ('Cunningham', 'Noelle', 'LOW'),
#  ('Cunningham', 'Beverly', 'MED'),
#  ('Dalton', 'Portia', 'LOW'),
#  ('Daniel', 'Beau', 'MED'),
#  ('Daugherty', 'Ciara', 'MED'),
#  ('Davenport', 'Clayton', 'LOW'),
#  ('Davidson', 'Kiayada', 'MED'),
#  ('Davis', 'Jeremy', 'MED'),
#  ('Dean', 'Suki', 'LOW'),
#  ('Decker', 'Raja', 'LOW'),
#  ('Decker', 'Cedric', 'MED'),
#  ('Dillard', 'Hedley', 'LOW'),
#  ('Dillard', 'Laurel', 'MED'),
#  ('Dominguez', 'Kasimir', 'MED'),
#  ('Donaldson', 'Aaron', 'LOW'),
#  ('Dorsey', 'Yoshio', 'LOW'),
#  ('Douglas', 'Alma', 'MED'),
#  ('Drake', 'Blythe', 'LOW'),
#  ('Duffy', 'Eliana', 'MED'),
#  ('Duke', 'Mariko', 'LOW'),
#  ('Duke', 'Melodie', 'LOW'),
#  ('Duke', 'Yasir', 'MED'),
#  ('Edwards', 'Marah', 'LOW'),
#  ('Elliott', 'Dieter', 'LOW'),
#  ('Elliott', 'Mara', 'LOW'),
#  ('Ellis', 'Dalton', 'MED'),
#  ('Estrada', 'Inez', 'LOW'),
#  ('Everett', 'MacKensie', 'LOW'),
#  ('Farmer', 'Tyler', 'MED'),
#  ('Ferguson', 'Amery', 'HIGH'),
#  ('Ferguson', 'Jared', 'MED'),
#  ('Fernandez', 'Walter', 'LOW'),
#  ('Fields', 'Kirsten', 'LOW'),
#  ('Figueroa', 'Coby', 'LOW'),
#  ('Fitzgerald', 'Hall', 'LOW'),
#  ('Fitzgerald', 'Veda', 'LOW'),
#  ('Fletcher', 'Fatima', 'LOW'),
#  ('Fletcher', 'Salvador', 'HIGH'),
#  ('Forbes', 'Bell', 'LOW'),
#  ('Foreman', 'Kristen', 'MED'),
#  ('Fowler', 'Lois', 'HIGH'),
#  ('Fox', 'Cecilia', 'HIGH'),
#  ('Franks', 'Ira', 'LOW'),
#  ('French', 'Hamish', 'LOW'),
#  ('Frost', 'Nicole', 'LOW'),
#  ('Fry', 'Britanney', 'HIGH'),
#  ('Frye', 'Fuller', 'LOW'),
#  ('Frye', 'Demetrius', 'MED'),
#  ('Fulton', 'Anne', 'LOW'),
#  ('Gaines', 'Gage', 'LOW'),
#  ('Gaines', 'Jayme', 'MED'),
#  ('Gallegos', 'Beatrice', 'MED'),
#  ('Gamble', 'Chester', 'LOW'),
#  ('Garcia', 'William', 'HIGH'),
#  ('Garrett', 'Jenette', 'LOW'),
#  ('Garrison', 'Galvin', 'MED'),
#  ('Garrison', 'Jolie', 'LOW'),
#  ('Garrison', 'Kiona', 'LOW'),
#  ('Garza', 'Kareem', 'MED'),
#  ('Gay', 'Faith', 'LOW'),
#  ('George', 'Eliana', 'LOW'),
#  ('Gibbs', 'Sonia', 'MED'),
#  ('Gibbs', 'Adara', 'LOW'),
#  ('Gibbs', 'Carly', 'MED'),
#  ('Gibson', 'Paul', 'LOW'),
#  ('Gilbert', 'Chelsea', 'MED'),
#  ('Gilbert', 'Destiny', 'MED'),
#  ('Gill', 'Rebecca', 'MED'),
#  ('Glass', 'Dean', 'HIGH'),
#  ('Glenn', 'Leigh', 'LOW'),
#  ('Glover', 'Nell', 'MED'),
#  ('Goff', 'Ray', 'MED'),
#  ('Golden', 'Jena', 'LOW'),
#  ('Gonzalez', 'Colton', 'LOW'),
#  ('Good', 'Willow', 'LOW'),
#  ('Goodwin', 'Orson', 'LOW'),
#  ('Gordon', 'Ashely', 'MED'),
#  ('Gordon', 'Leonard', 'LOW'),
#  ('Gould', 'Norman', 'MED'),
#  ('Graham', 'Amery', 'LOW'),
#  ('Gray', 'Sylvia', 'LOW'),
#  ('Griffin', 'Asher', 'MED'),
#  ('Grimes', 'Latifah', 'MED'),
#  ('Gutierrez', 'Rhoda', 'LOW'),
#  ('Gutierrez', 'Elijah', 'MED'),
#  ('Guzman', 'Ronan', 'LOW'),
#  ('Guzman', 'Hayley', 'LOW'),
#  ('Guzman', 'Wyoming', 'LOW'),
#  ('Hahn', 'Oren', 'LOW'),
#  ('Hale', 'Prescott', 'LOW'),
#  ('Hall', 'Sopoline', 'HIGH'),
#  ('Hall', 'Carissa', 'MED'),
#  ('Hamilton', 'Lee', 'MED'),
#  ('Hardin', 'Deborah', 'LOW'),
#  ('Harding', 'Amity', 'LOW'),
#  ('Harding', 'Fritz', 'LOW'),
#  ('Harrell', 'Aristotle', 'MED'),
#  ('Harrell', 'Griffin', 'MED'),
#  ('Harrell', 'Karyn', 'HIGH'),
#  ('Harris', 'Leilani', 'MED'),
#  ('Harris', 'Amaya', 'MED'),
#  ('Harrison', 'Rashad', 'HIGH'),
#  ('Hart', 'Phillip', 'LOW'),
#  ('Hart', 'Timon', 'LOW'),
#  ('Harvey', 'Tobias', 'MED'),
#  ('Hatfield', 'Avram', 'LOW'),
#  ('Hawkins', 'Ian', 'MED'),
#  ('Hayes', 'Beau', 'LOW'),
#  ('Hebert', 'Maya', 'LOW'),
#  ('Henson', 'Justine', 'MED'),
#  ('Herrera', 'Chava', 'LOW'),
#  ('Hester', 'Vielka', 'LOW'),
#  ('Hester', 'Quin', 'HIGH'),
#  ('Hicks', 'Zoe', 'LOW'),
#  ('Hinton', 'Rashad', 'LOW'),
#  ('Hodge', 'Jennifer', 'MED'),
#  ('Hodge', 'Chase', 'MED'),
#  ('Hodges', 'Alyssa', 'LOW'),
#  ('Hoffman', 'Yuri', 'MED'),
#  ('Holloway', 'Steel', 'LOW'),
#  ('Holt', 'Timon', 'LOW'),
#  ('Horne', 'Bethany', 'LOW'),
#  ('Horton', 'Carolyn', 'LOW'),
#  ('House', 'Brielle', 'LOW'),
#  ('House', 'Ivana', 'LOW'),
#  ('House', 'Emerson', 'MED'),
#  ('Howard', 'Cheryl', 'LOW'),
#  ('Howard', 'Kermit', 'LOW'),
#  ('Huber', 'Amelia', 'LOW'),
#  ('Humphrey', 'Dane', 'MED'),
#  ('Hunter', 'Ferdinand', 'LOW'),
#  ('Hurley', 'Jaden', 'HIGH'),
#  ('Hurst', 'Kai', 'MED'),
#  ('Jacobson', 'Baxter', 'MED'),
#  ('Jimenez', 'Carly', 'MED'),
#  ('Johns', 'Deborah', 'MED'),
#  ('Johns', 'Illiana', 'LOW'),
#  ('Johnston', 'Pearl', 'MED'),
#  ('Joseph', 'Kaseem', 'MED'),
#  ('Joyner', 'Ivana', 'MED'),
#  ('Kane', 'Macey', 'LOW'),
#  ('Keith', 'Ignatius', 'HIGH'),
#  ('Keith', 'Regan', 'LOW'),
#  ('Kelly', 'Angela', 'LOW'),
#  ('Kemp', 'Gwendolyn', 'MED'),
#  ('Kemp', 'Garrett', 'HIGH'),
#  ('Kennedy', 'Callie', 'MED'),
#  ('Key', 'Demetrius', 'MED'),
#  ('Kim', 'Kyla', 'LOW'),
#  ('King', 'Zelda', 'LOW'),
#  ('Kinney', 'Irene', 'LOW'),
#  ('Kinney', 'Armand', 'MED'),
#  ('Klein', 'Cheryl', 'LOW'),
#  ('Knapp', 'Channing', 'MED'),
#  ('Knight', 'Deacon', 'HIGH'),
#  ('Knowles', 'Erin', 'LOW'),
#  ('Knowles', 'Harlan', 'LOW'),
#  ('Langley', 'Cheryl', 'MED'),
#  ('Langley', 'Fatima', 'LOW'),
#  ('Leach', 'Kareem', 'LOW'),
#  ('Leblanc', 'Darrel', 'MED'),
#  ('Leblanc', 'Brooke', 'HIGH'),
#  ('Lee', 'Portia', 'LOW'),
#  ('Leon', 'Maggie', 'LOW'),
#  ('Leonard', 'Hoyt', 'HIGH'),
#  ('Lester', 'Lillith', 'LOW'),
#  ('Levy', 'Clare', 'LOW'),
#  ('Lewis', 'Buckminster', 'LOW'),
#  ('Little', 'Rowan', 'MED'),
#  ('Lopez', 'Rhiannon', 'MED'),
#  ('Love', 'Raja', 'MED'),
#  ('Love', 'Basia', 'LOW'),
#  ('Love', 'Nasim', 'MED'),
#  ('Lowe', 'Illana', 'LOW'),
#  ('Lowe', 'Sonia', 'LOW'),
#  ('Lowery', 'Maile', 'MED'),
#  ('Lucas', 'Reagan', 'MED'),
#  ('Luna', 'Kaitlin', 'LOW'),
#  ('Lynch', 'Adena', 'LOW'),
#  ('Lynn', 'Shana', 'MED'),
#  ('Lyons', 'Hamish', 'HIGH'),
#  ('Mack', 'Dawn', 'MED'),
#  ('Mack', 'Beau', 'LOW'),
#  ('Mann', 'Kalia', 'LOW'),
#  ('Marquez', 'Yvonne', 'MED'),
#  ('Marshall', 'Hilda', 'LOW'),
#  ('Mason', 'Russell', 'HIGH'),
#  ('Mathews', 'Lilah', 'MED'),
#  ('Mayer', 'Rashad', 'MED'),
#  ('Maynard', 'Lars', 'LOW'),
#  ('Mccarty', 'Jennifer', 'LOW'),
#  ('Mcclain', 'Rhoda', 'MED'),
#  ('Mcconnell', 'Lucy', 'MED'),
#  ('Mcgee', 'Bert', 'MED'),
#  ('Mcgowan', 'Rylee', 'LOW'),
#  ('Mcintyre', 'Yetta', 'MED'),
#  ('Mckay', 'Madonna', 'LOW'),
#  ('Meadows', 'Lael', 'LOW'),
#  ('Meadows', 'Nasim', 'MED'),
#  ('Melendez', 'Chase', 'MED'),
#  ('Melton', 'Kato', 'MED'),
#  ('Mendez', 'Colin', 'LOW'),
#  ('Mendoza', 'Dennis', 'LOW'),
#  ('Merritt', 'Hop', 'LOW'),
#  ('Michael', 'Harding', 'LOW'),
#  ('Michael', 'Sonya', 'LOW'),
#  ('Miles', 'Caesar', 'LOW'),
#  ('Mitchell', 'Abdul', 'LOW'),
#  ('Molina', 'Winifred', 'MED'),
#  ('Moon', 'Ray', 'MED'),
#  ('Moreno', 'Fitzgerald', 'LOW'),
#  ('Morin', 'Karen', 'LOW'),
#  ('Morris', 'Nathaniel', 'HIGH'),
#  ('Morrow', 'Jack', 'MED'),
#  ('Morse', 'Thor', 'MED'),
#  ('Moses', 'Denise', 'MED'),
#  ('Moss', 'Kylynn', 'LOW'),
#  ('Mueller', 'Aiko', 'MED'),
#  ('Mueller', 'Daniel', 'LOW'),
#  ('Murphy', 'Jin', 'LOW'),
#  ('Murray', 'Tatiana', 'MED'),
#  ('Myers', 'Ethan', 'LOW'),
#  ('Newman', 'Zorita', 'LOW'),
#  ('Newton', 'Adrienne', 'MED'),
#  ('Nielsen', 'Tanisha', 'MED'),
#  ('Nunez', 'Keith', 'HIGH'),
#  ('Odom', 'Macey', 'LOW'),
#  ('Olsen', 'Mercedes', 'LOW'),
#  ('Olson', 'Anastasia', 'HIGH'),
#  ('Olson', 'Xena', 'HIGH'),
#  ('Olson', 'Kiayada', 'HIGH'),
#  ('Oneil', 'Kylynn', 'HIGH'),
#  ('Osborne', 'Carolyn', 'LOW'),
#  ('Pacheco', 'Kylee', 'LOW'),
#  ('Park', 'Warren', 'MED'),
#  ('Parker', 'Shoshana', 'LOW'),
#  ('Parsons', 'Selma', 'LOW'),
#  ('Patrick', 'Kylan', 'MED'),
#  ('Pearson', 'Vivian', 'LOW'),
#  ('Peck', 'Yeo', 'LOW'),
#  ('Peck', 'Katell', 'LOW'),
#  ('Pena', 'Carl', 'LOW'),
#  ('Pena', 'Chastity', 'MED'),
#  ('Pennington', 'Sopoline', 'LOW'),
#  ('Perkins', 'Adara', 'LOW'),
#  ('Perry', 'Alfonso', 'HIGH'),
#  ('Petersen', 'Quamar', 'LOW'),
#  ('Petty', 'Miranda', 'MED'),
#  ('Pickett', 'Sebastian', 'LOW'),
#  ('Pittman', 'Nayda', 'LOW'),
#  ('Pope', 'Bethany', 'LOW'),
#  ('Potter', 'Brittany', 'LOW'),
#  ('Potts', 'Ebony', 'MED'),
#  ('Potts', 'Lucy', 'LOW'),
#  ('Preston', 'Noelle', 'MED'),
#  ('Prince', 'Hu', 'LOW'),
#  ('Prince', 'Fallon', 'LOW'),
#  ('Puckett', 'Edan', 'HIGH'),
#  ('Quinn', 'Dexter', 'MED'),
#  ('Quinn', 'Martin', 'HIGH'),
#  ('Ramsey', 'Ramona', 'MED'),
#  ('Randolph', 'Trevor', 'LOW'),
#  ('Ray', 'Donovan', 'MED'),
#  ('Reed', 'Neil', 'LOW'),
#  ('Reed', 'April', 'LOW'),
#  ('Reese', 'Cailin', 'MED'),
#  ('Reid', 'Courtney', 'LOW'),
#  ('Reyes', 'Reuben', 'MED'),
#  ('Richard', 'Autumn', 'LOW'),
#  ('Richmond', 'Abbot', 'LOW'),
#  ('Riddle', 'Anastasia', 'MED'),
#  ('Riddle', 'Shad', 'LOW'),
#  ('Rios', 'Kenyon', 'LOW'),
#  ('Rivas', 'Eagan', 'LOW'),
#  ('Rivas', 'Drew', 'LOW'),
#  ('Roach', 'Matthew', 'HIGH'),
#  ('Roberson', 'Randall', 'LOW'),
#  ('Roberson', 'Odysseus', 'LOW'),
#  ('Roberts', 'Riley', 'LOW'),
#  ('Robertson', 'Steel', 'LOW'),
#  ('Robertson', 'August', 'LOW'),
#  ('Robinson', 'Donna', 'LOW'),
#  ('Robles', 'Leonard', 'LOW'),
#  ('Rocha', 'Amal', 'LOW'),
#  ('Rocha', 'Sawyer', 'LOW'),
#  ('Rodgers', 'Nyssa', 'LOW'),
#  ('Romero', 'Kylie', 'LOW'),
#  ('Rosario', 'Daryl', 'MED'),
#  ('Roth', 'Paki', 'LOW'),
#  ('Rowland', 'Genevieve', 'MED'),
#  ('Roy', 'Christopher', 'MED'),
#  ('Salas', 'Victor', 'LOW'),
#  ('Salas', 'Cleo', 'MED'),
#  ('Sandoval', 'Cally', 'MED'),
#  ('Sanford', 'Sade', 'HIGH'),
#  ('Santiago', 'Steel', 'LOW'),
#  ('Santos', 'Harper', 'LOW'),
#  ('Saunders', 'Kalia', 'LOW'),
#  ('Sawyer', 'Reese', 'HIGH'),
#  ('Schmidt', 'Carson', 'LOW'),
#  ('Schneider', 'Farrah', 'LOW'),
#  ('Schneider', 'Lionel', 'MED'),
#  ('Schultz', 'Holly', 'LOW'),
#  ('Schultz', 'Quemby', 'LOW'),
#  ('Sears', 'Shea', 'LOW'),
#  ('Sellers', 'Jorden', 'LOW'),
#  ('Serrano', 'Katell', 'LOW'),
#  ('Sexton', 'Zane', 'LOW'),
#  ('Sexton', 'Francesca', 'MED'),
#  ('Shannon', 'Thane', 'LOW'),
#  ('Shaw', 'Sandra', 'LOW'),
#  ('Shepard', 'Drake', 'LOW'),
#  ('Shields', 'Noel', 'LOW'),
#  ('Simon', 'Ralph', 'MED'),
#  ('Sims', 'Zachary', 'LOW'),
#  ('Slater', 'Lisandra', 'LOW'),
#  ('Solomon', 'Xena', 'MED'),
#  ('Solomon', 'Oliver', 'LOW'),
#  ('Soto', 'Allistair', 'MED'),
#  ('Sparks', 'Quinlan', 'LOW'),
#  ('Stafford', 'Brett', 'LOW'),
#  ('Stark', 'Unity', 'MED'),
#  ('Steele', 'Jorden', 'LOW'),
#  ('Stein', 'Cecilia', 'MED'),
#  ('Stephenson', 'Jamal', 'LOW'),
#  ('Stewart', 'Akeem', 'LOW'),
#  ('Stokes', 'Jason', 'LOW'),
#  ('Stokes', 'Chastity', 'MED'),
#  ('Stone', 'Germaine', 'LOW'),
#  ('Stuart', 'Fredericka', 'LOW'),
#  ('Summers', 'Idola', 'LOW'),
#  ('Summers', 'Nash', 'LOW'),
#  ('Summers', 'Naida', 'LOW'),
#  ('Sutton', 'Hiram', 'MED'),
#  ('Sweeney', 'Garrison', 'LOW'),
#  ('Sweeney', 'Jonas', 'MED'),
#  ('Sweeney', 'Macy', 'HIGH'),
#  ('Sweet', 'Xyla', 'LOW'),
#  ('Sykes', 'Boris', 'LOW'),
#  ('Tanner', 'Nayda', 'MED'),
#  ('Tate', 'Sarah', 'MED'),
#  ('Thompson', 'Michelle', 'LOW'),
#  ('Trevino', 'Orli', 'LOW'),
#  ('Trevino', 'Owen', 'LOW'),
#  ('Trujillo', 'Caldwell', 'LOW'),
#  ('Underwood', 'Igor', 'LOW'),
#  ('Vasquez', 'Willow', 'LOW'),
#  ('Vaughn', 'Leonard', 'MED'),
#  ('Vega', 'Nevada', 'LOW'),
#  ('Velasquez', 'Gregory', 'LOW'),
#  ('Walker', 'Leah', 'MED'),
#  ('Wallace', 'Ian', 'MED'),
#  ('Wallace', 'Galvin', 'MED'),
#  ('Walls', 'Molly', 'MED'),
#  ('Walls', 'Jerome', 'LOW'),
#  ('Walters', 'Evelyn', 'LOW'),
#  ('Walton', 'Avram', 'HIGH'),
#  ('Ward', 'Doris', 'LOW'),
#  ('Ware', 'MacKenzie', 'LOW'),
#  ('Warner', 'Travis', 'LOW'),
#  ('Waters', 'Lee', 'LOW'),
#  ('Watts', 'Charde', 'LOW'),
#  ('Watts', 'Lamar', 'LOW'),
#  ('Weaver', 'Basil', 'HIGH'),
#  ('Webb', 'William', 'MED'),
#  ('Weiss', 'Aiko', 'LOW'),
#  ('Wells', 'Len', 'LOW'),
#  ('Wells', 'Colt', 'LOW'),
#  ('Wheeler', 'Brenda', 'LOW'),
#  ('Whitaker', 'Briar', 'LOW'),
#  ('Whitaker', 'Ava', 'LOW'),
#  ('White', 'Berk', 'LOW'),
#  ('White', 'Justina', 'MED'),
#  ('Whitehead', 'Lance', 'HIGH'),
#  ('Whitney', 'Sara', 'MED'),
#  ('Wiggins', 'Janna', 'MED'),
#  ('Wiggins', 'Igor', 'MED'),
#  ('Wiley', 'Tanek', 'LOW'),
#  ('William', 'Quentin', 'LOW'),
#  ('Williams', 'Derek', 'LOW'),
#  ('Williams', 'Whitney', 'LOW'),
#  ('Williamson', 'Baker', 'HIGH'),
#  ('Wise', 'Flavia', 'LOW'),
#  ('Wise', 'Illana', 'LOW'),
#  ('Wise', 'Fritz', 'LOW'),
#  ('Woodard', 'Bertha', 'MED'),
#  ('Woods', 'Quemby', 'LOW'),
#  ('Wooten', 'Deanna', 'HIGH'),
#  ('Wright', 'Uta', 'LOW'),
#  ('Wyatt', 'Brooke', 'MED'),
#  ('Wyatt', 'Amber', 'MED'),
#  ('York', 'Willow', 'MED'),
#  ('York', 'Adena', 'HIGH'),
#  ('Zamora', 'Cecilia', 'LOW')]

# %%
session.close()
